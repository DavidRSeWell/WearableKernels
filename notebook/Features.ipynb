# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
os.chdir('../')

# %%
from Wearables.wisdm import WisdmData

# %%
data_path = "/Users/davidsewell/MLData/"
wisdm_data = WisdmData(data_path)
# Out:
# Could not process id for file .DS_Store

# %%
subject_watch_data = wisdm_data.load_subject_data(1600,"watch","accel")

# %%
from Wearables.features import _median_spectral_power, _magnitude, _apply_bandpass

# %%
subject_watch_data[["x","y","z"]].plot()
# Out:
# <AxesSubplot:>

# %%
# Magnitude feature
filtered_ = _magnitude(subject_watch_data[["x","y","z"]].to_numpy())

# %%
plt.plot(filtered_)

# %%
# Bandpass
banded_data_ = _apply_bandpass(subject_watch_data[["x","y","z"]].to_numpy())
